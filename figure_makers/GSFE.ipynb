# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.ticker import MultipleLocator
# %matplotlib inline

# %% [markdown]
# ### Gr

# %%
b = np.load("/Users/jonathanlu/Documents/tvGr/b.npy")
bx, by = b.T
energies = np.load("/Users/jonathanlu/Documents/tvGr/e.npy")
b.shape
# Out:
# (6561, 2)

# %%
fig, ax = plt.subplots(figsize=(6,4))
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
plt.rc('font', size=FONT_SIZE)
cf = ax.tricontourf(bx, by, energies-np.min(energies), levels=501, cmap="RdGy")
cb = plt.colorbar(cf, ax=ax, shrink=0.65, ticks=[0,5,10,15,20])
# ax.set_xlabel(r"$b_x$ $(\mathrm{\AA})$", fontsize=18)
ax.set_aspect('equal') # prevent axis stretching
plt.tight_layout()
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(1))
plt.xticks(fontsize=FONT_SIZE)
plt.yticks(fontsize=FONT_SIZE)
plt.savefig('/Users/jonathanlu/Documents/data_mlph/GSFE_Gr.png')

# %% [markdown]
# ### MoS2

# %%
b = np.load("/Users/jonathanlu/Documents/tvMoS2/b.npy")[:,:2]
bx, by = b.T
energies = np.load("/Users/jonathanlu/Documents/tvMoS2/e.npy")
b.shape
# Out:
# (6561, 2)

# %%
fig, ax = plt.subplots(figsize=(6,4))
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
plt.rc('font', size=FONT_SIZE)
cf = ax.tricontourf(bx, by, energies-np.min(energies), levels=501, cmap='BrBG', vmin=0)
cb = plt.colorbar(cf, ax=ax, shrink=0.65, ticks=[0, 15,30,45,60])
ax.set_aspect('equal') # prevent axis stretching
plt.tight_layout()
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(1))
plt.xticks(fontsize=FONT_SIZE)
plt.yticks(fontsize=FONT_SIZE)
plt.savefig('/Users/jonathanlu/Documents/data_mlph/GSFE_MoS2.png')

# %% [markdown]
# ## Het

# %%
b = np.load("/Users/jonathanlu/Documents/tvHet/b.npy")[:,:2]
bx, by = b.T
energies = np.load("/Users/jonathanlu/Documents/tvHet/e.npy")
b.shape
# Out:
# (6561, 2)

# %%
fig, ax = plt.subplots(figsize=(6,4))
matplotlib.rcParams['mathtext.fontset'] = 'stix'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
plt.rc('font', size=FONT_SIZE)
cf = ax.tricontourf(bx, by, energies-np.min(energies), levels=501, cmap='PuOr', vmin=0)
cb = plt.colorbar(cf, ax=ax, shrink=0.65, ticks=[0, 15,30,45,60])
ax.set_aspect('equal') # prevent axis stretching
plt.tight_layout()
ax.xaxis.set_major_locator(MultipleLocator(1))
ax.yaxis.set_major_locator(MultipleLocator(1))
plt.xticks(fontsize=FONT_SIZE)
plt.yticks(fontsize=FONT_SIZE)
plt.savefig('/Users/jonathanlu/Documents/data_mlph/GSFE_Het.png')
